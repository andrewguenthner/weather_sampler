# %% [markdown]
# # WeatherPy
# ----
# ### Background / Issues
# * Goal:  understand how the weather changes as one approaches the equator
# * Basic approach:  Use openweathermap API to sample weather in cities using the citipy dataset and examine the effects of latitude
# * Issues:  "City weather" is quite different from weather in general.  Cities are on land, tend to be near large bodies of water, and tend not to be at high elevation, in polar regions, on rugged terrain, in deserts, etc.  So, the more specific question that we will answer is "how does the weather in cities change as one approaches the equator?"
# * Please see the "README" deisgn doc for more detailed discussion and instructions for use.
#
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import openweathermapy.core as owm
import time
import urllib
from haversine import haversine
# Import API key
from config import api_key

# Incorporated haversine library to calculate distances
# from haversine import haversine

# Input File (CSV)
input_data_file = 'citipy/worldcities.csv'

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Output log File (TXT)
output_log = 'output_data/log.txt'

# %% [markdown]
# ### Code Parameters

# %%
# Constants
# lat_radius will control the size of the search radius (in distance equal to deg lat, 
# which means 1.0 = 111 km, 2.0 = 222 km, etc.  Smaller = longer time to build city list
# but larger = less perfect sampling of population.  Note that city locations are not
# meaningful at less than 10 km resolution, that is, lat_radius < 0.1.  
lat_radius = 1.0
# To help with server load, the notebook will acquire weather for data_size cities, but
# will do so by running up to max_batches queries of batch_size.  Because not every
# query may be successful, max_batches is recommended to allow data_size with some margin.
# To keep from making unlimited queries, however, the search will end even if data_size records
# are not returned.  
batch_size = 20
data_size = 500
max_batches = 40
# wlr is a 'padded' margin of water to land area on Earth's surface (actually about 3 to 1)
# This parameter can be increased if the notebook warns you it can't find enough cities
wlr = 6        #Use an integer

# %% [markdown]
# ### Prepare City Data
# By importing directly from the csv, we lose the kd-tree structure from citipy, but we gain the ability to
# do the appropriate math.

# %%
# Read the DataFrame, sort by latitude (then longitude), and use the latitude as the index
city_df = pd.read_csv(input_data_file).sort_values(by=['Latitude','Longitude']).set_index('Latitude', drop=False)
# A latitude-based index will speed up the city search greatly later.
city_df.head()
# Out:
#            Country          City   Latitude   Longitude
# Latitude
# -54.800000      ar       ushuaia -54.800000  -68.300000
# -53.150000      cl  punta arenas -53.150000  -70.916667
# -51.622613      ar  rio gallegos -51.622613  -69.218127
# -46.600000      nz         bluff -46.600000  168.333333
# -46.400000      nz  invercargill -46.400000  168.350000

# %% [markdown]
# ## Generate Cities List

# %%
def getcities(batch=batch_size, radius = lat_radius, found = []):
    '''Returns a list of city names with length equal to batch.  In practice, this means transforming
    the latitude distribution by an inverse cosine to give appropriately gerater probability to points
    along the equator and vanishingly small probability of points approaching the poles. Once a point
    is selected, a search for cities using the global city_df is made, and the nearest city having
    a distance less than 'radius' (in latitude degrees, 1 deg = 111.13 km) is selected.'''
# List for holding city names and search count.  For safety, we will terminate at a fixed number of searches.
    cities = []
    searches = 0
    max_searches = wlr * batch  #wlr = approx area ratio of water to land on Earth, with some margin for error
# Loop through until we get the required number of successes
    while len(cities) <  batch and searches <= max_searches:
        city_name = ''
        max_dist = 111.13 * radius  #Converts latitude degrees to km, based on average radius of Earth
        # Choose a random point on Earth's surface
        lat = 180.0 / 3.1416 *  np.arccos(2 * np.random.rand() -1) - 90
        lng = 360.0 * np.random.rand() - 180.0
        # The search is a two-part filter.  The first is a direct filter of any place with the wrong lats 
        # We do not filter on lngs because the modular arithmetic and nonlinearity make it quite complex.  
        search_df = city_df.loc[lat - radius : lat + radius,:]
        # Now we can search through a much smaller list to look for the nearest city
        # Here we use df.iat for fast look-up, with only numbers for indices (city name = 1, lat = 2, lng = 3)
        if not search_df.empty:
            #Many latitudes will have no cities, so these get skipped altogether
            for ix in range(len(search_df)):
                dist = haversine((lat, lng),(search_df.iat[ix,2],search_df.iat[ix,3]))
            # The second part of the search is a simple minimum finder initialized to the maximum permitted value.
                if dist < max_dist and (search_df.iat[ix,1] not in cities) and (search_df.iat[ix,1 not in found):
                    city_name = search_df.iat[ix,1]
                    max_dist = dist
        # Append the nearest city if we found one
        if city_name:
            cities.append(city_name)
        searches += 1
        if searches > max_searches:
            print('Not finding many cities. Please increase the parameters lat_radius and/or wlr.')
    print(f'Batch complete, {len(cities)} found.')
    return cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create settings for API call
settings = {'units':'imperial','appid':api_key}
# Set up objects to hold results and count of attempts and successes
batch_num = 0
citycount = 0
cityfound = []
countryfound = []
tempfound = []
humidfound = []
windfound = []
cloudfound = []
latfound = []
lngfound = []
whenfound = []
# Get the data in batches so as to not overwhelm server ...
with open(output_log,'w') as f:
    while citycount < data_size and batch_num < max_batches:
        # Initialize a batch
        batch_num += 1
        attempt_num = 0
        f.write(f'Beginning data collection batch {batch_num}:\n')
        print(f'Building batch number {batch_num}')
        # Get cities in a batch
        citylist = getcities(batch_size, lat_radius, cityfound)
        while attempt_num < len(citylist):
            # Now attempt to access one city at a time
            city = citylist[attempt_num]
            attempt_num += 1
            # Reset temp holders, using physically meaningless values to indicate missing data
            tmpcity, tmpcountry, tmptemp, tmphumid, tmpwind, tmpclouds, tmplat, tmplng = '','',-99,-99,-99,-99,-99,-199
            # Log request
            print('Requesting weather for ' + city + '...')
            reqtime = datetime.now()
            f.write('Request city: ' + city + ' at ' + reqtime.strftime('%m/%d/%Y, %H:%M:%S') + '\n')
            # Make request from openweathermap
            try:
                weather = owm.get_current(city, **settings)
                # Store results in temporary objects for checking, enforce types for later
                tmpcity = weather['name']
                tmpcountry = weather['sys']['country']
                tmptemp = float(weather['main']['temp'])
                tmphumid = float(weather['main']['humidity'])
                tmpwind = float(weather['wind']['speed'])
                tmpclouds = float(weather['clouds']['all'])
                tmplat = float(weather['coord']['lat'])
                tmplng = float(weather['coord']['lon'])
                # Log data 
                reqtime = datetime.now()
                f.write('Response at ' + reqtime.strftime('%m/%d/%Y, %H:%M:%S') + '\n')
                f.write('City: ' + tmpcity + ' Country: ' + tmpcountry)
                f.write(' Temp: ' + str(tmptemp) + ' Humidity: ' + str(tmphumid))       
                f.write(' Wind: ' + str(tmpwind) + ' Cloud cover: ' + str(tmpclouds))    
                f.write(' Lat: ' + str(tmplat) + ' Lng: ' + str(tmplng) + '\n')
            except urllib.request.HTTPError:
                print('HTTP Error')
                f.write('HTTP Request Failed\n')
            except KeyError:
                print('Weather data not found.')
                f.write('Weather data not found.\n')
            # Only record data if all missing values are filled in with meaningful data (when possible to check)
            if all ((tmpcity != '', tmpcountry !='', tmptemp > -99, tmphumid >=0,\
                        tmpwind >=0, tmpclouds >=0, tmplat >=-90, tmplng >=-180)):
                print('Succes. City: '+ tmpcity + ' found. Raw data in file')
                f.write('Success.  Appending data.\n')
                # In this case, increment success counter and append data to lists
                citycount += 1
                cityfound.append(tmpcity)
                countryfound.append(tmpcountry)
                tempfound.append(tmptemp)
                humidfound.append(tmphumid)
                windfound.append(tmpwind)
                cloudfound.append(tmpclouds)
                latfound.append(tmplat)
                lngfound.append(tmplng)
                whenfound.append(reqtime)
            else: #If not all parameters were successful, note it and move on to next.
                print('There was a problem with this request.  Noted in file')
                f.write('Data does not meet criteria and will not be used.\n')
        if len(cityfound) < data_size:  #Pause requests if we need to get more
            print('Giving the server a break ...')
            time.sleep(3)
# Out:
# Building batch number 1
# Batch complete, 20 found.
# Requesting weather for tupik...
# Succes. City: Tupik found. Raw data in file
# Requesting weather for vologda...
# Succes. City: Vologda found. Raw data in file
# Requesting weather for maumere...
# Succes. City: Maumere found. Raw data in file
# Requesting weather for kurumkan...
# Succes. City: Kurumkan found. Raw data in file
# Requesting weather for benghazi...
# Succes. City: Benghazi found. Raw data in file
# Requesting weather for ust-tsilma...
# Succes. City: Ust-Tsilma found. Raw data in file
# Requesting weather for sigli...
# Succes. City: Sigli found. Raw data in file
# Requesting weather for yuancheng...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for netrakona...
# Succes. City: Netrakona found. Raw data in file
# Requesting weather for maniitsoq...
# Succes. City: Maniitsoq found. Raw data in file
# Requesting weather for umm jarr...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for orda...
# Succes. City: Orda found. Raw data in file
# Requesting weather for espinosa...
# Succes. City: Espinosa found. Raw data in file
# Requesting weather for baloda bazar...
# Succes. City: Baloda Bazar found. Raw data in file
# Requesting weather for atka...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for karachi...
# Succes. City: Karachi found. Raw data in file
# Requesting weather for mekhe...
# Succes. City: Mekhe found. Raw data in file
# Requesting weather for tombouctou...
# Succes. City: Timbuktu found. Raw data in file
# Requesting weather for juxtlahuaca...
# Succes. City: Juxtlahuaca found. Raw data in file
# Requesting weather for kapoeta...
# HTTP Error
# There was a problem with this request.  Noted in file
# Giving the server a break ...
# Building batch number 2
# Batch complete, 20 found.
# Requesting weather for rio grande...
# Succes. City: Rio Grande found. Raw data in file
# Requesting weather for kiunga...
# Succes. City: Kiunga found. Raw data in file
# Requesting weather for north myrtle beach...
# Succes. City: North Myrtle Beach found. Raw data in file
# Requesting weather for bouca...
# Succes. City: Bouca found. Raw data in file
# Requesting weather for khorion...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for qandala...
# Succes. City: Qandala found. Raw data in file
# Requesting weather for santa barbara...
# Succes. City: Santa Barbara found. Raw data in file
# Requesting weather for nizhneyansk...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for mangaldai...
# Succes. City: Mangaldai found. Raw data in file
# Requesting weather for miandrivazo...
# Succes. City: Miandrivazo found. Raw data in file
# Requesting weather for melfort...
# Succes. City: Melfort found. Raw data in file
# Requesting weather for palmas...
# Succes. City: Palmas found. Raw data in file
# Requesting weather for balakovo...
# Succes. City: Balakovo found. Raw data in file
# Requesting weather for atuona...
# Succes. City: Atuona found. Raw data in file
# Requesting weather for odweyne...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for weihe...
# Succes. City: Weihe found. Raw data in file
# Requesting weather for adet...
# Succes. City: Adet found. Raw data in file
# Requesting weather for rabo de peixe...
# Succes. City: Rabo de Peixe found. Raw data in file
# Requesting weather for tucurui...
# Succes. City: Tucurui found. Raw data in file
# Requesting weather for alekseyevka...
# Succes. City: Alekseyevka found. Raw data in file
# Giving the server a break ...
# Building batch number 3
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 14 found.
# Requesting weather for catamarca...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for port lavaca...
# Succes. City: Port Lavaca found. Raw data in file
# Requesting weather for sherlovaya gora...
# Succes. City: Sherlovaya Gora found. Raw data in file
# Requesting weather for ngozi...
# Succes. City: Ngozi found. Raw data in file
# Requesting weather for vryburg...
# Succes. City: Vryburg found. Raw data in file
# Requesting weather for fort abbas...
# Succes. City: Fort Abbas found. Raw data in file
# Requesting weather for dwarka...
# Succes. City: Dwarka found. Raw data in file
# Requesting weather for porto-vecchio...
# Succes. City: Porto-Vecchio found. Raw data in file
# Requesting weather for turayf...
# Succes. City: Turayf found. Raw data in file
# Requesting weather for kolokani...
# Succes. City: Kolokani found. Raw data in file
# Requesting weather for patratu...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for hohoe...
# Succes. City: Hohoe found. Raw data in file
# Requesting weather for kushmurun...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for koulamoutou...
# Succes. City: Koulamoutou found. Raw data in file
# Giving the server a break ...
# Building batch number 4
# Batch complete, 20 found.
# Requesting weather for kesennuma...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for varhaug...
# Succes. City: Varhaug found. Raw data in file
# Requesting weather for linguere...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for jian...
# Succes. City: Jian found. Raw data in file
# Requesting weather for marrakesh...
# Succes. City: Marrakesh found. Raw data in file
# Requesting weather for tendo...
# Succes. City: Tendo found. Raw data in file
# Requesting weather for barrhead...
# Succes. City: Barrhead found. Raw data in file
# Requesting weather for shively...
# Succes. City: Shively found. Raw data in file
# Requesting weather for moose factory...
# Succes. City: Moose Factory found. Raw data in file
# Requesting weather for jining...
# Succes. City: Jining found. Raw data in file
# Requesting weather for alcudia...
# Succes. City: Alcudia found. Raw data in file
# Requesting weather for bria...
# Succes. City: Bria found. Raw data in file
# Requesting weather for kokoda...
# Succes. City: Kokoda found. Raw data in file
# Requesting weather for maracaibo...
# Succes. City: Maracaibo found. Raw data in file
# Requesting weather for lar...
# Succes. City: Lar found. Raw data in file
# Requesting weather for kushikino...
# Succes. City: Kushikino found. Raw data in file
# Requesting weather for ubrique...
# Succes. City: Ubrique found. Raw data in file
# Requesting weather for derbent...
# Succes. City: Derbent found. Raw data in file
# Requesting weather for navahrudak...
# Succes. City: Navahrudak found. Raw data in file
# Requesting weather for graaff-reinet...
# Succes. City: Graaff-Reinet found. Raw data in file
# Giving the server a break ...
# Building batch number 5
# Batch complete, 20 found.
# Requesting weather for odweyne...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for komsomolskiy...
# Succes. City: Komsomolskiy found. Raw data in file
# Requesting weather for bom jardim...
# Succes. City: Bom Jardim found. Raw data in file
# Requesting weather for keningau...
# Succes. City: Keningau found. Raw data in file
# Requesting weather for bajil...
# Succes. City: Bajil found. Raw data in file
# Requesting weather for akbarpur...
# Succes. City: Akbarpur found. Raw data in file
# Requesting weather for mastung...
# Succes. City: Mastung found. Raw data in file
# Requesting weather for hearst...
# Succes. City: Hearst found. Raw data in file
# Requesting weather for qinzhou...
# Succes. City: Qinzhou found. Raw data in file
# Requesting weather for kabalo...
# Succes. City: Kabalo found. Raw data in file
# Requesting weather for huntsville...
# Succes. City: Huntsville found. Raw data in file
# Requesting weather for escanaba...
# Succes. City: Escanaba found. Raw data in file
# Requesting weather for rab...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for obo...
# Succes. City: Obo found. Raw data in file
# Requesting weather for boyuibe...
# Succes. City: Boyuibe found. Raw data in file
# Requesting weather for kotelnich...
# Succes. City: Kotelnich found. Raw data in file
# Requesting weather for sao raimundo nonato...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for laurel...
# Succes. City: Laurel found. Raw data in file
# Requesting weather for ushibuka...
# Succes. City: Ushibuka found. Raw data in file
# Requesting weather for port augusta...
# Succes. City: Port Augusta found. Raw data in file
# Giving the server a break ...
# Building batch number 6
# Batch complete, 20 found.
# Requesting weather for preston...
# Succes. City: Preston found. Raw data in file
# Requesting weather for tombouctou...
# Succes. City: Timbuktu found. Raw data in file
# Requesting weather for wadi musa...
# Succes. City: Wadi Musa found. Raw data in file
# Requesting weather for horsham...
# Succes. City: Horsham found. Raw data in file
# Requesting weather for nisia floresta...
# Succes. City: Nisia Floresta found. Raw data in file
# Requesting weather for derzhavinsk...
# Succes. City: Derzhavinsk found. Raw data in file
# Requesting weather for mweka...
# Succes. City: Mweka found. Raw data in file
# Requesting weather for yumen...
# Succes. City: Yumen found. Raw data in file
# Requesting weather for coalinga...
# Succes. City: Coalinga found. Raw data in file
# Requesting weather for pravda...
# Succes. City: Pravda found. Raw data in file
# Requesting weather for ha...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for urengoy...
# Succes. City: Urengoy found. Raw data in file
# Requesting weather for la ronge...
# Succes. City: La Ronge found. Raw data in file
# Requesting weather for godfrey...
# Succes. City: Godfrey found. Raw data in file
# Requesting weather for ha tinh...
# Succes. City: Ha Tinh found. Raw data in file
# Requesting weather for urucara...
# Succes. City: Urucara found. Raw data in file
# Requesting weather for calawag...
# Succes. City: Calawag found. Raw data in file
# Requesting weather for kinshasa...
# Succes. City: Kinshasa found. Raw data in file
# Requesting weather for serta...
# Succes. City: Serta found. Raw data in file
# Requesting weather for morden...
# Succes. City: Morden found. Raw data in file
# Giving the server a break ...
# Building batch number 7
# Batch complete, 20 found.
# Requesting weather for mentok...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for aleksandrov gay...
# Succes. City: Aleksandrov Gay found. Raw data in file
# Requesting weather for babynino...
# Succes. City: Babynino found. Raw data in file
# Requesting weather for lhokseumawe...
# Succes. City: Lhokseumawe found. Raw data in file
# Requesting weather for hashtrud...
# Succes. City: Hashtrud found. Raw data in file
# Requesting weather for madarounfa...
# Succes. City: Madarounfa found. Raw data in file
# Requesting weather for filingue...
# Succes. City: Filingue found. Raw data in file
# Requesting weather for ransang...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for durango...
# Succes. City: Durango found. Raw data in file
# Requesting weather for marshall...
# Succes. City: Marshall found. Raw data in file
# Requesting weather for poum...
# Succes. City: Poum found. Raw data in file
# Requesting weather for emporia...
# Succes. City: Emporia found. Raw data in file
# Requesting weather for ankang...
# Succes. City: Ankang found. Raw data in file
# Requesting weather for dubai...
# Succes. City: Dubai found. Raw data in file
# Requesting weather for umtata...
# Succes. City: Umtata found. Raw data in file
# Requesting weather for pendleton...
# Succes. City: Pendleton found. Raw data in file
# Requesting weather for baruun-urt...
# Succes. City: Baruun-Urt found. Raw data in file
# Requesting weather for vicuna...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for los barrios...
# Succes. City: Los Barrios found. Raw data in file
# Requesting weather for bako...
# Succes. City: Bako found. Raw data in file
# Giving the server a break ...
# Building batch number 8
# Batch complete, 20 found.
# Requesting weather for heihe...
# Succes. City: Heihe found. Raw data in file
# Requesting weather for tsaratanana...
# Succes. City: Tsaratanana found. Raw data in file
# Requesting weather for tommot...
# Succes. City: Tommot found. Raw data in file
# Requesting weather for scottsburgh...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for rongcheng...
# Succes. City: Rongcheng found. Raw data in file
# Requesting weather for obregon...
# Succes. City: Obregon found. Raw data in file
# Requesting weather for constitucion...
# Succes. City: Constitucion found. Raw data in file
# Requesting weather for yovon...
# Succes. City: Yovon found. Raw data in file
# Requesting weather for shambu...
# Succes. City: Shambu found. Raw data in file
# Requesting weather for aktau...
# Succes. City: Aktau found. Raw data in file
# Requesting weather for vila...
# Succes. City: Vila found. Raw data in file
# Requesting weather for malumfashi...
# Succes. City: Malumfashi found. Raw data in file
# Requesting weather for ukiah...
# Succes. City: Ukiah found. Raw data in file
# Requesting weather for afmadu...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for chissamba...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for trabzon...
# Succes. City: Trabzon found. Raw data in file
# Requesting weather for kango...
# Succes. City: Kango found. Raw data in file
# Requesting weather for guiratinga...
# Succes. City: Guiratinga found. Raw data in file
# Requesting weather for nguru...
# Succes. City: Nguru found. Raw data in file
# Requesting weather for mala...
# Succes. City: Mala found. Raw data in file
# Giving the server a break ...
# Building batch number 9
# Batch complete, 20 found.
# Requesting weather for ust-nera...
# Succes. City: Ust-Nera found. Raw data in file
# Requesting weather for jiuquan...
# Succes. City: Jiuquan found. Raw data in file
# Requesting weather for pyaozerskiy...
# Succes. City: Pyaozerskiy found. Raw data in file
# Requesting weather for vieste...
# Succes. City: Vieste found. Raw data in file
# Requesting weather for mufumbwe...
# Succes. City: Mufumbwe found. Raw data in file
# Requesting weather for coihaique...
# Succes. City: Coihaique found. Raw data in file
# Requesting weather for lavrentiya...
# Succes. City: Lavrentiya found. Raw data in file
# Requesting weather for grand-santi...
# Succes. City: Grand-Santi found. Raw data in file
# Requesting weather for ust-kamchatsk...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for chivay...
# Succes. City: Chivay found. Raw data in file
# Requesting weather for caluquembe...
# Succes. City: Caluquembe found. Raw data in file
# Requesting weather for rongcheng...
# Succes. City: Rongcheng found. Raw data in file
# Requesting weather for mandera...
# Succes. City: Mandera found. Raw data in file
# Requesting weather for pulandian...
# Succes. City: Pulandian found. Raw data in file
# Requesting weather for jales...
# Succes. City: Jales found. Raw data in file
# Requesting weather for nanga eboko...
# Succes. City: Nanga Eboko found. Raw data in file
# Requesting weather for tancanhuitz...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for batticaloa...
# Succes. City: Batticaloa found. Raw data in file
# Requesting weather for uvira...
# Succes. City: Uvira found. Raw data in file
# Requesting weather for ntungamo...
# Succes. City: Ntungamo found. Raw data in file
# Giving the server a break ...
# Building batch number 10
# Batch complete, 20 found.
# Requesting weather for jaguaruna...
# Succes. City: Jaguaruna found. Raw data in file
# Requesting weather for derzhavinsk...
# Succes. City: Derzhavinsk found. Raw data in file
# Requesting weather for tvoroyri...
# Succes. City: Tvoroyri found. Raw data in file
# Requesting weather for wencheng...
# Succes. City: Wencheng found. Raw data in file
# Requesting weather for maryborough...
# Succes. City: Maryborough found. Raw data in file
# Requesting weather for port blair...
# Succes. City: Port Blair found. Raw data in file
# Requesting weather for pleasanton...
# Succes. City: Pleasanton found. Raw data in file
# Requesting weather for buritis...
# Succes. City: Buritis found. Raw data in file
# Requesting weather for semme...
# Succes. City: Semme found. Raw data in file
# Requesting weather for mildura...
# Succes. City: Mildura found. Raw data in file
# Requesting weather for javanrud...
# Succes. City: Javanrud found. Raw data in file
# Requesting weather for northam...
# Succes. City: Northam found. Raw data in file
# Requesting weather for marsabit...
# Succes. City: Marsabit found. Raw data in file
# Requesting weather for tahoua...
# Succes. City: Tahoua found. Raw data in file
# Requesting weather for vangaindrano...
# Succes. City: Vangaindrano found. Raw data in file
# Requesting weather for visby...
# Succes. City: Visby found. Raw data in file
# Requesting weather for assiniboia...
# Succes. City: Assiniboia found. Raw data in file
# Requesting weather for eirunepe...
# Succes. City: Eirunepe found. Raw data in file
# Requesting weather for lang son...
# Succes. City: Lang Son found. Raw data in file
# Requesting weather for sembe...
# HTTP Error
# There was a problem with this request.  Noted in file
# Giving the server a break ...
# Building batch number 11
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 15 found.
# Requesting weather for sabathu...
# Succes. City: Sabathu found. Raw data in file
# Requesting weather for zyryanka...
# Succes. City: Zyryanka found. Raw data in file
# Requesting weather for flin flon...
# Succes. City: Flin Flon found. Raw data in file
# Requesting weather for asosa...
# Succes. City: Asosa found. Raw data in file
# Requesting weather for monteagudo...
# Succes. City: Monteagudo found. Raw data in file
# Requesting weather for betanzos...
# Succes. City: Betanzos found. Raw data in file
# Requesting weather for rock springs...
# Succes. City: Rock Springs found. Raw data in file
# Requesting weather for sampit...
# Succes. City: Sampit found. Raw data in file
# Requesting weather for queenstown...
# Succes. City: Queenstown found. Raw data in file
# Requesting weather for el wasta...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for severobaykalsk...
# Succes. City: Severobaykalsk found. Raw data in file
# Requesting weather for boa vista...
# Succes. City: Boa Vista found. Raw data in file
# Requesting weather for hoima...
# Succes. City: Hoima found. Raw data in file
# Requesting weather for jaca...
# Succes. City: Jaca found. Raw data in file
# Requesting weather for fuente de oro...
# Succes. City: Fuente de Oro found. Raw data in file
# Giving the server a break ...
# Building batch number 12
# Batch complete, 20 found.
# Requesting weather for zyryanovsk...
# Succes. City: Zyryanovsk found. Raw data in file
# Requesting weather for kinanah...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for jaguey grande...
# Succes. City: Jaguey Grande found. Raw data in file
# Requesting weather for suileng...
# Succes. City: Suileng found. Raw data in file
# Requesting weather for dandong...
# Succes. City: Dandong found. Raw data in file
# Requesting weather for iqaluit...
# Succes. City: Iqaluit found. Raw data in file
# Requesting weather for eyl...
# Succes. City: Eyl found. Raw data in file
# Requesting weather for moskovskiy...
# Succes. City: Moskovskiy found. Raw data in file
# Requesting weather for kaoma...
# Succes. City: Kaoma found. Raw data in file
# Requesting weather for sai buri...
# Succes. City: Sai Buri found. Raw data in file
# Requesting weather for jeremoabo...
# Succes. City: Jeremoabo found. Raw data in file
# Requesting weather for la tuque...
# Succes. City: La Tuque found. Raw data in file
# Requesting weather for miri...
# Succes. City: Miri found. Raw data in file
# Requesting weather for bangkal...
# Succes. City: Bangkal found. Raw data in file
# Requesting weather for raiwala...
# Succes. City: Raiwala found. Raw data in file
# Requesting weather for azangaro...
# Succes. City: Azangaro found. Raw data in file
# Requesting weather for ambunti...
# Succes. City: Ambunti found. Raw data in file
# Requesting weather for cedar city...
# Succes. City: Cedar City found. Raw data in file
# Requesting weather for braganca...
# Succes. City: Braganca found. Raw data in file
# Requesting weather for monteagudo...
# Succes. City: Monteagudo found. Raw data in file
# Giving the server a break ...
# Building batch number 13
# Batch complete, 20 found.
# Requesting weather for kurilsk...
# Succes. City: Kurilsk found. Raw data in file
# Requesting weather for alihe...
# Succes. City: Alihe found. Raw data in file
# Requesting weather for oktyabrskiy...
# Succes. City: Oktyabrskiy found. Raw data in file
# Requesting weather for verkhovazhye...
# Succes. City: Verkhovazhye found. Raw data in file
# Requesting weather for nanga eboko...
# Succes. City: Nanga Eboko found. Raw data in file
# Requesting weather for francisco sa...
# Succes. City: Francisco Sa found. Raw data in file
# Requesting weather for gourcy...
# Succes. City: Gourcy found. Raw data in file
# Requesting weather for primore...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for barbacoas...
# Succes. City: Barbacoas found. Raw data in file
# Requesting weather for bousso...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for mazatlan...
# Succes. City: Mazatlan found. Raw data in file
# Requesting weather for koygorodok...
# Succes. City: Koygorodok found. Raw data in file
# Requesting weather for karkaralinsk...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for hamilton...
# Succes. City: Hamilton found. Raw data in file
# Requesting weather for cuamba...
# Succes. City: Cuamba found. Raw data in file
# Requesting weather for kuhestan...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for jacareacanga...
# Succes. City: Jacareacanga found. Raw data in file
# Requesting weather for zamora...
# Succes. City: Zamora found. Raw data in file
# Requesting weather for bestobe...
# Succes. City: Bestobe found. Raw data in file
# Requesting weather for udankudi...
# Succes. City: Udankudi found. Raw data in file
# Giving the server a break ...
# Building batch number 14
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 16 found.
# Requesting weather for raga...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for zavodouspenskoye...
# Succes. City: Zavodouspenskoye found. Raw data in file
# Requesting weather for port elizabeth...
# Succes. City: Port Elizabeth found. Raw data in file
# Requesting weather for khobi...
# Succes. City: Khobi found. Raw data in file
# Requesting weather for peremyshl...
# Succes. City: Peremyshl found. Raw data in file
# Requesting weather for la plata...
# Succes. City: La Plata found. Raw data in file
# Requesting weather for oistins...
# Succes. City: Oistins found. Raw data in file
# Requesting weather for rabo de peixe...
# Succes. City: Rabo de Peixe found. Raw data in file
# Requesting weather for kalmar...
# Succes. City: Kalmar found. Raw data in file
# Requesting weather for frankfort...
# Succes. City: Frankfort found. Raw data in file
# Requesting weather for lumphat...
# Succes. City: Lumphat found. Raw data in file
# Requesting weather for tripoli...
# Succes. City: Tripoli found. Raw data in file
# Requesting weather for rio tercero...
# Succes. City: Rio Tercero found. Raw data in file
# Requesting weather for belen...
# Succes. City: Belen found. Raw data in file
# Requesting weather for pangody...
# Succes. City: Pangody found. Raw data in file
# Requesting weather for izvestkovyy...
# Succes. City: Izvestkovyy found. Raw data in file
# Giving the server a break ...
# Building batch number 15
# Batch complete, 20 found.
# Requesting weather for stephenville...
# Succes. City: Stephenville found. Raw data in file
# Requesting weather for tasbuget...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for rawson...
# Succes. City: Rawson found. Raw data in file
# Requesting weather for port pirie...
# Succes. City: Port Pirie found. Raw data in file
# Requesting weather for port keats...
# Succes. City: Port Keats found. Raw data in file
# Requesting weather for sroda wielkopolska...
# Succes. City: Sroda Wielkopolska found. Raw data in file
# Requesting weather for kadaya...
# Succes. City: Kadaya found. Raw data in file
# Requesting weather for semey...
# Succes. City: Semey found. Raw data in file
# Requesting weather for yanan...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for beyneu...
# Succes. City: Beyneu found. Raw data in file
# Requesting weather for pushkar...
# Succes. City: Pushkar found. Raw data in file
# Requesting weather for panguna...
# Succes. City: Panguna found. Raw data in file
# Requesting weather for villazon...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for alto baudo...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for norrtalje...
# Succes. City: Norrtalje found. Raw data in file
# Requesting weather for bongandanga...
# Succes. City: Bongandanga found. Raw data in file
# Requesting weather for falkenberg...
# Succes. City: Falkenberg found. Raw data in file
# Requesting weather for kutum...
# Succes. City: Kutum found. Raw data in file
# Requesting weather for grafton...
# Succes. City: Grafton found. Raw data in file
# Requesting weather for kahului...
# Succes. City: Kahului found. Raw data in file
# Giving the server a break ...
# Building batch number 16
# Batch complete, 20 found.
# Requesting weather for yenagoa...
# Succes. City: Yenagoa found. Raw data in file
# Requesting weather for marabba...
# Succes. City: Marabba found. Raw data in file
# Requesting weather for ylivieska...
# Succes. City: Ylivieska found. Raw data in file
# Requesting weather for santiago del estero...
# Succes. City: Santiago del Estero found. Raw data in file
# Requesting weather for mecca...
# Succes. City: Mecca found. Raw data in file
# Requesting weather for pelagiada...
# Succes. City: Pelagiada found. Raw data in file
# Requesting weather for baykit...
# Succes. City: Baykit found. Raw data in file
# Requesting weather for fort saint john...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for mustasaari...
# Succes. City: Mustasaari found. Raw data in file
# Requesting weather for nador...
# Succes. City: Nador found. Raw data in file
# Requesting weather for vuktyl...
# Succes. City: Vuktyl found. Raw data in file
# Requesting weather for sasaram...
# Succes. City: Sasaram found. Raw data in file
# Requesting weather for hurghada...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for tarakan...
# Succes. City: Tarakan found. Raw data in file
# Requesting weather for mukerian...
# Succes. City: Mukerian found. Raw data in file
# Requesting weather for sakhon nakhon...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for bintulu...
# Succes. City: Bintulu found. Raw data in file
# Requesting weather for ijui...
# Succes. City: Ijui found. Raw data in file
# Requesting weather for xinzhi...
# Succes. City: Xinzhi found. Raw data in file
# Requesting weather for angleton...
# Succes. City: Angleton found. Raw data in file
# Giving the server a break ...
# Building batch number 17
# Batch complete, 20 found.
# Requesting weather for north bend...
# Succes. City: North Bend found. Raw data in file
# Requesting weather for woodward...
# Succes. City: Woodward found. Raw data in file
# Requesting weather for santiago del estero...
# Succes. City: Santiago del Estero found. Raw data in file
# Requesting weather for kreminna...
# Succes. City: Kreminna found. Raw data in file
# Requesting weather for sambava...
# Succes. City: Sambava found. Raw data in file
# Requesting weather for ridgetown...
# Succes. City: Ridgetown found. Raw data in file
# Requesting weather for kampot...
# Succes. City: Kampot found. Raw data in file
# Requesting weather for ambilobe...
# Succes. City: Ambilobe found. Raw data in file
# Requesting weather for mwinilunga...
# Succes. City: Mwinilunga found. Raw data in file
# Requesting weather for nokaneng...
# Succes. City: Nokaneng found. Raw data in file
# Requesting weather for aitape...
# Succes. City: Aitape found. Raw data in file
# Requesting weather for el retorno...
# Succes. City: El Retorno found. Raw data in file
# Requesting weather for montepuez...
# Succes. City: Montepuez found. Raw data in file
# Requesting weather for la plata...
# Succes. City: La Plata found. Raw data in file
# Requesting weather for moa...
# Succes. City: Moa found. Raw data in file
# Requesting weather for uaua...
# Succes. City: Uaua found. Raw data in file
# Requesting weather for san fernando...
# Succes. City: San Fernando found. Raw data in file
# Requesting weather for vlakhokerasea...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for spassk-dalniy...
# Succes. City: Spassk-Dalniy found. Raw data in file
# Requesting weather for parker...
# Succes. City: Parker found. Raw data in file
# Giving the server a break ...
# Building batch number 18
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 19 found.
# Requesting weather for hobbs...
# Succes. City: Hobbs found. Raw data in file
# Requesting weather for novobirilyussy...
# Succes. City: Novobirilyussy found. Raw data in file
# Requesting weather for mpanda...
# Succes. City: Mpanda found. Raw data in file
# Requesting weather for kamenskoye...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for kaabong...
# Succes. City: Kaabong found. Raw data in file
# Requesting weather for nkhotakota...
# Succes. City: Nkhotakota found. Raw data in file
# Requesting weather for carlyle...
# Succes. City: Carlyle found. Raw data in file
# Requesting weather for odienne...
# Succes. City: Odienne found. Raw data in file
# Requesting weather for dalbandin...
# Succes. City: Dalbandin found. Raw data in file
# Requesting weather for voyvozh...
# Succes. City: Voyvozh found. Raw data in file
# Requesting weather for chingirlau...
# Succes. City: Chingirlau found. Raw data in file
# Requesting weather for bozuyuk...
# Succes. City: Bozuyuk found. Raw data in file
# Requesting weather for clarence town...
# Succes. City: Clarence Town found. Raw data in file
# Requesting weather for qinhuangdao...
# Succes. City: Qinhuangdao found. Raw data in file
# Requesting weather for vilhena...
# Succes. City: Vilhena found. Raw data in file
# Requesting weather for coro...
# Succes. City: Coro found. Raw data in file
# Requesting weather for alice springs...
# Succes. City: Alice Springs found. Raw data in file
# Requesting weather for sabancuy...
# Succes. City: Sabancuy found. Raw data in file
# Requesting weather for harrisonville...
# Succes. City: Harrisonville found. Raw data in file
# Giving the server a break ...
# Building batch number 19
# Batch complete, 20 found.
# Requesting weather for chaohu...
# Succes. City: Chaohu found. Raw data in file
# Requesting weather for karakol...
# Succes. City: Karakol found. Raw data in file
# Requesting weather for sidi ali...
# Succes. City: Sidi Ali found. Raw data in file
# Requesting weather for makubetsu...
# Succes. City: Makubetsu found. Raw data in file
# Requesting weather for paragominas...
# Succes. City: Paragominas found. Raw data in file
# Requesting weather for tibiri...
# Succes. City: Tibiri found. Raw data in file
# Requesting weather for mityana...
# Succes. City: Mityana found. Raw data in file
# Requesting weather for kitimat...
# Succes. City: Kitimat found. Raw data in file
# Requesting weather for san ignacio...
# Succes. City: San Ignacio found. Raw data in file
# Requesting weather for novopokrovka...
# Succes. City: Novopokrovka found. Raw data in file
# Requesting weather for bejar...
# Succes. City: Bejar found. Raw data in file
# Requesting weather for pesochnoye...
# Succes. City: Pesochnoye found. Raw data in file
# Requesting weather for cortez...
# Succes. City: Cortez found. Raw data in file
# Requesting weather for paramonga...
# Succes. City: Paramonga found. Raw data in file
# Requesting weather for cacoal...
# Succes. City: Cacoal found. Raw data in file
# Requesting weather for manyoni...
# Succes. City: Manyoni found. Raw data in file
# Requesting weather for el tigre...
# Succes. City: El Tigre found. Raw data in file
# Requesting weather for orahovac...
# Succes. City: Orahovac found. Raw data in file
# Requesting weather for zvishavane...
# Succes. City: Zvishavane found. Raw data in file
# Requesting weather for kayankulam...
# Succes. City: Kayankulam found. Raw data in file
# Giving the server a break ...
# Building batch number 20
# Batch complete, 20 found.
# Requesting weather for serramanna...
# Succes. City: Serramanna found. Raw data in file
# Requesting weather for stromness...
# Succes. City: Stromness found. Raw data in file
# Requesting weather for spilimbergo...
# Succes. City: Spilimbergo found. Raw data in file
# Requesting weather for ormond beach...
# Succes. City: Ormond Beach found. Raw data in file
# Requesting weather for bouca...
# Succes. City: Bouca found. Raw data in file
# Requesting weather for ponta do sol...
# Succes. City: Ponta do Sol found. Raw data in file
# Requesting weather for rolim de moura...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for wagar...
# Succes. City: Wagar found. Raw data in file
# Requesting weather for zyryanka...
# Succes. City: Zyryanka found. Raw data in file
# Requesting weather for miranorte...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for garissa...
# Succes. City: Garissa found. Raw data in file
# Requesting weather for caracuaro...
# Succes. City: Caracuaro found. Raw data in file
# Requesting weather for polis...
# Succes. City: Polis found. Raw data in file
# Requesting weather for wajir...
# Succes. City: Wajir found. Raw data in file
# Requesting weather for ancud...
# Succes. City: Ancud found. Raw data in file
# Requesting weather for jining...
# Succes. City: Jining found. Raw data in file
# Requesting weather for hermanus...
# Succes. City: Hermanus found. Raw data in file
# Requesting weather for velikiy ustyug...
# Succes. City: Velikiy Ustyug found. Raw data in file
# Requesting weather for puerto baquerizo moreno...
# Succes. City: Puerto Baquerizo Moreno found. Raw data in file
# Requesting weather for higuey...
# HTTP Error
# There was a problem with this request.  Noted in file
# Giving the server a break ...
# Building batch number 21
# Batch complete, 20 found.
# Requesting weather for kuzhener...
# Succes. City: Kuzhener found. Raw data in file
# Requesting weather for drumheller...
# Succes. City: Drumheller found. Raw data in file
# Requesting weather for papasquiaro...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for katwijk...
# Succes. City: Katwijk found. Raw data in file
# Requesting weather for wabash...
# Succes. City: Wabash found. Raw data in file
# Requesting weather for umm durman...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for madarounfa...
# Succes. City: Madarounfa found. Raw data in file
# Requesting weather for maneadero...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for dera din panah...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for abu dhabi...
# Succes. City: Abu Dhabi found. Raw data in file
# Requesting weather for turayf...
# Succes. City: Turayf found. Raw data in file
# Requesting weather for amarpur...
# Succes. City: Amarpur found. Raw data in file
# Requesting weather for yuancheng...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for turka...
# Succes. City: Turka found. Raw data in file
# Requesting weather for nguiu...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for shache...
# Succes. City: Shache found. Raw data in file
# Requesting weather for bogolyubovo...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for gariaband...
# Succes. City: Gariaband found. Raw data in file
# Requesting weather for aginskoye...
# Succes. City: Aginskoye found. Raw data in file
# Requesting weather for chalus...
# Succes. City: Chalus found. Raw data in file
# Giving the server a break ...
# Building batch number 22
# Batch complete, 20 found.
# Requesting weather for constitucion...
# Succes. City: Constitucion found. Raw data in file
# Requesting weather for oak forest...
# Succes. City: Oak Forest found. Raw data in file
# Requesting weather for sergeyevka...
# Succes. City: Sergeyevka found. Raw data in file
# Requesting weather for vanino...
# Succes. City: Vanino found. Raw data in file
# Requesting weather for berlevag...
# Succes. City: Berlevag found. Raw data in file
# Requesting weather for kuala terengganu...
# Succes. City: Kuala Terengganu found. Raw data in file
# Requesting weather for birnin kebbi...
# Succes. City: Birnin Kebbi found. Raw data in file
# Requesting weather for yanan...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for choix...
# Succes. City: Choix found. Raw data in file
# Requesting weather for yuzhno-yeniseyskiy...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for turhal...
# Succes. City: Turhal found. Raw data in file
# Requesting weather for margherita...
# Succes. City: Margherita found. Raw data in file
# Requesting weather for clyde river...
# Succes. City: Clyde River found. Raw data in file
# Requesting weather for sofiysk...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for pucallpa...
# Succes. City: Pucallpa found. Raw data in file
# Requesting weather for sarapul...
# Succes. City: Sarapul found. Raw data in file
# Requesting weather for edea...
# Succes. City: Edea found. Raw data in file
# Requesting weather for aberdeen...
# Succes. City: Aberdeen found. Raw data in file
# Requesting weather for eldorado...
# Succes. City: Eldorado found. Raw data in file
# Requesting weather for manicore...
# Succes. City: Manicore found. Raw data in file
# Giving the server a break ...
# Building batch number 23
# Batch complete, 20 found.
# Requesting weather for outlook...
# Succes. City: Outlook found. Raw data in file
# Requesting weather for nioro...
# Succes. City: Nioro found. Raw data in file
# Requesting weather for shwebo...
# Succes. City: Shwebo found. Raw data in file
# Requesting weather for sitges...
# Succes. City: Sitges found. Raw data in file
# Requesting weather for lewistown...
# Succes. City: Lewistown found. Raw data in file
# Requesting weather for otane...
# Succes. City: Otane found. Raw data in file
# Requesting weather for maha sarakham...
# Succes. City: Maha Sarakham found. Raw data in file
# Requesting weather for calvinia...
# Succes. City: Calvinia found. Raw data in file
# Requesting weather for coihueco...
# Succes. City: Coihueco found. Raw data in file
# Requesting weather for geresk...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for laem sing...
# Succes. City: Laem Sing found. Raw data in file
# Requesting weather for feijo...
# Succes. City: Feijo found. Raw data in file
# Requesting weather for satun...
# Succes. City: Satun found. Raw data in file
# Requesting weather for juelsminde...
# Succes. City: Juelsminde found. Raw data in file
# Requesting weather for barentsburg...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for trujillo...
# Succes. City: Trujillo found. Raw data in file
# Requesting weather for shubarshi...
# Succes. City: Shubarshi found. Raw data in file
# Requesting weather for usoke...
# Succes. City: Usoke found. Raw data in file
# Requesting weather for stanger...
# Succes. City: Stanger found. Raw data in file
# Requesting weather for zhanakorgan...
# Succes. City: Zhanakorgan found. Raw data in file
# Giving the server a break ...
# Building batch number 24
# Batch complete, 20 found.
# Requesting weather for alakurtti...
# Succes. City: Alakurtti found. Raw data in file
# Requesting weather for ocampo...
# Succes. City: Ocampo found. Raw data in file
# Requesting weather for kavaratti...
# Succes. City: Kavaratti found. Raw data in file
# Requesting weather for bad iburg...
# Succes. City: Bad Iburg found. Raw data in file
# Requesting weather for gulariya...
# Succes. City: Gulariya found. Raw data in file
# Requesting weather for victor harbor...
# Succes. City: Victor Harbor found. Raw data in file
# Requesting weather for kipushi...
# Succes. City: Kipushi found. Raw data in file
# Requesting weather for manjo...
# Succes. City: Manjo found. Raw data in file
# Requesting weather for bhag...
# Succes. City: Bhag found. Raw data in file
# Requesting weather for tukuran...
# Succes. City: Tukuran found. Raw data in file
# Requesting weather for hamada...
# Succes. City: Hamada found. Raw data in file
# Requesting weather for tazovskiy...
# Succes. City: Tazovskiy found. Raw data in file
# Requesting weather for diplo...
# Succes. City: Diplo found. Raw data in file
# Requesting weather for kegayli...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for pedernales...
# Succes. City: Pedernales found. Raw data in file
# Requesting weather for alabaster...
# Succes. City: Alabaster found. Raw data in file
# Requesting weather for kawai...
# Succes. City: Kawai found. Raw data in file
# Requesting weather for tucuma...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for pathalgaon...
# Succes. City: Pathalgaon found. Raw data in file
# Requesting weather for sesheke...
# Succes. City: Sesheke found. Raw data in file
# Giving the server a break ...
# Building batch number 25
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 16 found.
# Requesting weather for birao...
# Succes. City: Birao found. Raw data in file
# Requesting weather for plastun...
# Succes. City: Plastun found. Raw data in file
# Requesting weather for remanso...
# Succes. City: Remanso found. Raw data in file
# Requesting weather for umba...
# Succes. City: Umba found. Raw data in file
# Requesting weather for tansen...
# Succes. City: Tansen found. Raw data in file
# Requesting weather for los llanos de aridane...
# Succes. City: Los Llanos de Aridane found. Raw data in file
# Requesting weather for ponazyrevo...
# Succes. City: Ponazyrevo found. Raw data in file
# Requesting weather for macusani...
# Succes. City: Macusani found. Raw data in file
# Requesting weather for fram...
# Succes. City: Fram found. Raw data in file
# Requesting weather for otradnoye...
# Succes. City: Otradnoye found. Raw data in file
# Requesting weather for jinchengjiang...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for aranda de duero...
# Succes. City: Aranda de Duero found. Raw data in file
# Requesting weather for chyhyryn...
# Succes. City: Chyhyryn found. Raw data in file
# Requesting weather for arrifes...
# Succes. City: Arrifes found. Raw data in file
# Requesting weather for tuktoyaktuk...
# Succes. City: Tuktoyaktuk found. Raw data in file
# Requesting weather for oskarshamn...
# Succes. City: Oskarshamn found. Raw data in file
# Giving the server a break ...
# Building batch number 26
# Batch complete, 20 found.
# Requesting weather for manthani...
# Succes. City: Manthani found. Raw data in file
# Requesting weather for passo de camaragibe...
# Succes. City: Passo de Camaragibe found. Raw data in file
# Requesting weather for luba...
# Succes. City: Luba found. Raw data in file
# Requesting weather for kloulklubed...
# Succes. City: Kloulklubed found. Raw data in file
# Requesting weather for rae bareli...
# Succes. City: Rae Bareli found. Raw data in file
# Requesting weather for kidal...
# Succes. City: Kidal found. Raw data in file
# Requesting weather for arlit...
# Succes. City: Arlit found. Raw data in file
# Requesting weather for sarh...
# Succes. City: Sarh found. Raw data in file
# Requesting weather for chanika...
# Succes. City: Chanika found. Raw data in file
# Requesting weather for maraa...
# Succes. City: Maraa found. Raw data in file
# Requesting weather for telsiai...
# Succes. City: Telsiai found. Raw data in file
# Requesting weather for trento...
# Succes. City: Trento found. Raw data in file
# Requesting weather for nizwa...
# Succes. City: Nizwa found. Raw data in file
# Requesting weather for honolulu...
# Succes. City: Honolulu found. Raw data in file
# Requesting weather for leninskoye...
# Succes. City: Leninskoye found. Raw data in file
# Requesting weather for calderitas...
# Succes. City: Calderitas found. Raw data in file
# Requesting weather for trat...
# Succes. City: Trat found. Raw data in file
# Requesting weather for corn island...
# Succes. City: Corn Island found. Raw data in file
# Requesting weather for turtkul...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for zaria...
# Succes. City: Zaria found. Raw data in file
# Giving the server a break ...
# Building batch number 27
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 15 found.
# Requesting weather for popondetta...
# Succes. City: Popondetta found. Raw data in file
# Requesting weather for marmande...
# Succes. City: Marmande found. Raw data in file
# Requesting weather for san fernando...
# Succes. City: San Fernando found. Raw data in file
# Requesting weather for ayagoz...
# Succes. City: Ayagoz found. Raw data in file
# Requesting weather for iracoubo...
# Succes. City: Iracoubo found. Raw data in file
# Requesting weather for kamenka...
# Succes. City: Kamenka found. Raw data in file
# Requesting weather for luebo...
# Succes. City: Luebo found. Raw data in file
# Requesting weather for thatta...
# Succes. City: Thatta found. Raw data in file
# Requesting weather for ji-parana...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for baiyin...
# Succes. City: Baiyin found. Raw data in file
# Requesting weather for barentsburg...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for manggar...
# Succes. City: Manggar found. Raw data in file
# Requesting weather for campana...
# Succes. City: Campana found. Raw data in file
# Requesting weather for strelitsa...
# Succes. City: Strelitsa found. Raw data in file
# Requesting weather for gaogou...
# Succes. City: Gaogou found. Raw data in file
# Giving the server a break ...
# Building batch number 28
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 20 found.
# Requesting weather for yashalta...
# Succes. City: Yashalta found. Raw data in file
# Requesting weather for oleksandrivka...
# Succes. City: Oleksandrivka found. Raw data in file
# Requesting weather for luzhou...
# Succes. City: Luzhou found. Raw data in file
# Requesting weather for castillo de teayo...
# Succes. City: Castillo de Teayo found. Raw data in file
# Requesting weather for fergus falls...
# Succes. City: Fergus Falls found. Raw data in file
# Requesting weather for cedar city...
# Succes. City: Cedar City found. Raw data in file
# Requesting weather for sete lagoas...
# Succes. City: Sete Lagoas found. Raw data in file
# Requesting weather for chauk...
# Succes. City: Chauk found. Raw data in file
# Requesting weather for mersin...
# Succes. City: Mersin found. Raw data in file
# Requesting weather for boda...
# Succes. City: Boda found. Raw data in file
# Requesting weather for mau aima...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for tayoltita...
# Succes. City: Tayoltita found. Raw data in file
# Requesting weather for pontes e lacerda...
# Succes. City: Pontes e Lacerda found. Raw data in file
# Requesting weather for pinheiro machado...
# Succes. City: Pinheiro Machado found. Raw data in file
# Requesting weather for oga...
# Succes. City: Oga found. Raw data in file
# Requesting weather for bakchar...
# Succes. City: Bakchar found. Raw data in file
# Requesting weather for moses lake...
# Succes. City: Moses Lake found. Raw data in file
# Requesting weather for vodnyy...
# Succes. City: Vodnyy found. Raw data in file
# Requesting weather for poso...
# Succes. City: Poso found. Raw data in file
# Requesting weather for khrystynivka...
# Succes. City: Khrystynivka found. Raw data in file
# Giving the server a break ...
# Building batch number 29
# Batch complete, 20 found.
# Requesting weather for sterling...
# Succes. City: Sterling found. Raw data in file
# Requesting weather for albion...
# Succes. City: Albion found. Raw data in file
# Requesting weather for kuna...
# Succes. City: Kuna found. Raw data in file
# Requesting weather for escanaba...
# Succes. City: Escanaba found. Raw data in file
# Requesting weather for henties bay...
# Succes. City: Henties Bay found. Raw data in file
# Requesting weather for noumea...
# Succes. City: Noumea found. Raw data in file
# Requesting weather for pimenta bueno...
# Succes. City: Pimenta Bueno found. Raw data in file
# Requesting weather for goya...
# Succes. City: Goya found. Raw data in file
# Requesting weather for zavetnoye...
# Succes. City: Zavetnoye found. Raw data in file
# Requesting weather for husavik...
# Succes. City: Husavik found. Raw data in file
# Requesting weather for mabamba...
# Succes. City: Mabamba found. Raw data in file
# Requesting weather for mae sot...
# Succes. City: Mae Sot found. Raw data in file
# Requesting weather for tungkang...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for pukhrayan...
# Succes. City: Pukhrayan found. Raw data in file
# Requesting weather for mongo...
# Succes. City: Mongo found. Raw data in file
# Requesting weather for thabazimbi...
# Succes. City: Thabazimbi found. Raw data in file
# Requesting weather for erenhot...
# Succes. City: Erenhot found. Raw data in file
# Requesting weather for nadapuram...
# Succes. City: Nadapuram found. Raw data in file
# Requesting weather for bury saint edmunds...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for miraflores...
# Succes. City: Miraflores found. Raw data in file
# Giving the server a break ...
# Building batch number 30
# Not finding many cities. Please increase the parameters lat_radius and/or wlr.
# Batch complete, 18 found.
# Requesting weather for montrose...
# Succes. City: Montrose found. Raw data in file
# Requesting weather for ambovombe...
# Succes. City: Ambovombe found. Raw data in file
# Requesting weather for belokurikha...
# Succes. City: Belokurikha found. Raw data in file
# Requesting weather for santa maria...
# Succes. City: Santa Maria found. Raw data in file
# Requesting weather for riyadh...
# Succes. City: Riyadh found. Raw data in file
# Requesting weather for biak...
# Succes. City: Biak found. Raw data in file
# Requesting weather for kakamigahara...
# Succes. City: Kakamigahara found. Raw data in file
# Requesting weather for ouesso...
# Succes. City: Ouesso found. Raw data in file
# Requesting weather for bouar...
# Succes. City: Bouar found. Raw data in file
# Requesting weather for tshikapa...
# Succes. City: Tshikapa found. Raw data in file
# Requesting weather for vershino-darasunskiy...
# Succes. City: Vershino-Darasunskiy found. Raw data in file
# Requesting weather for zeitz...
# Succes. City: Zeitz found. Raw data in file
# Requesting weather for harnosand...
# Succes. City: Harnosand found. Raw data in file
# Requesting weather for angra...
# HTTP Error
# There was a problem with this request.  Noted in file
# Requesting weather for vizinga...
# Succes. City: Vizinga found. Raw data in file
# Requesting weather for fayetteville...
# Succes. City: Fayetteville found. Raw data in file
# Requesting weather for barguzin...
# Succes. City: Barguzin found. Raw data in file
# Requesting weather for gaoual...
# Succes. City: Gaoual found. Raw data in file

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Generate DataFrame with the results
weather_df = pd.DataFrame({'City':cityfound,'Country':countryfound,'Latitude':latfound,
                          'Longitude':lngfound,'Time':whenfound,'Temperature (deg F)':tempfound,
                          'Humidity (%)':humidfound,'Wind Speed (mph)':windfound,'Cloud Cover (%)':cloudfound})
weather_df.to_csv(output_data_file)
weather_df
# Out:
#                      City Country  Latitude  Longitude  \
# 0                   Tupik      RU     54.43     119.94
# 1                 Vologda      RU     59.22      39.89
# 2                 Maumere      ID     -8.63     122.22
# 3                Kurumkan      RU     54.33     110.32
# 4                Benghazi      LY     32.12      20.07
# 5              Ust-Tsilma      RU     65.44      52.15
# 6                   Sigli      ID      5.38      95.96
# 7               Netrakona      BD     24.88      90.72
# 8               Maniitsoq      GL     65.42     -52.90
# 9                    Orda      RU     57.20      56.91
# 10               Espinosa      BR    -14.92     -42.81
# 11           Baloda Bazar      IN     21.65      82.17
# 12                Karachi      PK     24.87      67.03
# 13                  Mekhe      SN     15.11     -16.62
# 14               Timbuktu      ML     16.77      -3.01
# 15            Juxtlahuaca      MX     17.43     -99.15
# 16             Rio Grande      BR    -32.03     -52.10
# 17                 Kiunga      PG     -6.12     141.30
# 18     North Myrtle Beach      US     33.83     -78.68
# 19                  Bouca      CF      6.51      18.28
# 20                Qandala      SO     11.47      49.87
# 21          Santa Barbara      US     34.42    -119.70
# 22              Mangaldai      IN     26.43      92.03
# 23            Miandrivazo      MG    -19.53      45.46
# 24                Melfort      CA     52.87    -104.61
# 25                 Palmas      BR    -10.18     -48.33
# 26               Balakovo      RU     52.02      47.82
# 27                 Atuona      PF     -9.80    -139.03
# 28                  Weihe      CN     32.99     105.33
# 29                   Adet      ET     11.26      37.49
# ..                    ...     ...       ...        ...
# 477                Noumea      NC    -22.28     166.46
# 478         Pimenta Bueno      BR    -11.68     -61.19
# 479                  Goya      AR    -29.14     -59.27
# 480             Zavetnoye      RU     47.12      43.89
# 481               Husavik      CA     50.56     -96.99
# 482               Mabamba      TZ     -3.60      30.50
# 483               Mae Sot      MM     16.71      98.57
# 484             Pukhrayan      IN     26.23      79.84
# 485                 Mongo      CF      4.83      22.92
# 486            Thabazimbi      ZA    -24.59      27.41
# 487               Erenhot      CN     43.65     111.97
# 488             Nadapuram      IN     11.70      75.65
# 489            Miraflores      CO      5.20     -73.14
# 490              Montrose      AU    -37.81     145.34
# 491             Ambovombe      MG    -25.18      46.09
# 492           Belokurikha      RU     52.00      84.99
# 493           Santa Maria      BR    -29.69     -53.81
# 494                Riyadh      SA     24.63      46.72
# 495                  Biak      ID     -0.91     122.88
# 496          Kakamigahara      JP     35.40     136.85
# 497                Ouesso      CG      1.61      16.05
# 498                 Bouar      CF      5.94      15.59
# 499              Tshikapa      CD     -6.42      20.79
# 500  Vershino-Darasunskiy      RU     52.35     115.52
# 501                 Zeitz      DE     51.05      12.13
# 502             Harnosand      SE     62.63      17.94
# 503               Vizinga      RU     61.08      50.08
# 504          Fayetteville      US     36.06     -94.16
# 505              Barguzin      RU     53.62     109.63
# 506                Gaoual      GN     11.75     -13.20
#
#                           Time  Temperature (deg F)  Humidity (%)  \
# 0   2019-03-28 22:34:53.005643                23.18          38.0
# 1   2019-03-28 22:34:53.282849                29.75          94.0
# 2   2019-03-28 22:34:53.670821                82.58         100.0
# 3   2019-03-28 22:34:54.075568                21.56          64.0
# 4   2019-03-28 22:34:54.646886                58.55         100.0
# 5   2019-03-28 22:34:54.920679                28.58          72.0
# 6   2019-03-28 22:34:55.201182                83.57          94.0
# 7   2019-03-28 22:34:55.717215                88.70          67.0
# 8   2019-03-28 22:34:55.989566                13.82          62.0
# 9   2019-03-28 22:34:56.556590                33.17          98.0
# 10  2019-03-28 22:34:56.851241                67.10          91.0
# 11  2019-03-28 22:34:57.389159                95.00          21.0
# 12  2019-03-28 22:34:57.930325                89.60          33.0
# 13  2019-03-28 22:34:58.310972                68.00          82.0
# 14  2019-03-28 22:34:58.620652                76.73          36.0
# 15  2019-03-28 22:34:58.915074                49.19          89.0
# 16  2019-03-28 22:35:03.339182                72.14          82.0
# 17  2019-03-28 22:35:04.217185                87.53          67.0
# 18  2019-03-28 22:35:04.571245                45.43          93.0
# 19  2019-03-28 22:35:04.895631                75.92          72.0
# 20  2019-03-28 22:35:06.404820                79.70          60.0
# 21  2019-03-28 22:35:07.116249                52.16          93.0
# 22  2019-03-28 22:35:09.596808                86.00          48.0
# 23  2019-03-28 22:35:09.890539                80.24          68.0
# 24  2019-03-28 22:35:10.253620                37.40          74.0
# 25  2019-03-28 22:35:10.963173                75.20         100.0
# 26  2019-03-28 22:35:11.911282                30.02          97.0
# 27  2019-03-28 22:35:12.657996                80.69         100.0
# 28  2019-03-28 22:35:13.532463                68.27          23.0
# 29  2019-03-28 22:35:14.978354                63.32          80.0
# ..                         ...                  ...           ...
# 477 2019-03-28 22:44:39.788886                89.60          52.0
# 478 2019-03-28 22:44:40.056533                71.87          99.0
# 479 2019-03-28 22:44:40.354531                69.17          81.0
# 480 2019-03-28 22:44:40.715579                36.86          74.0
# 481 2019-03-28 22:44:41.117658                26.53          78.0
# 482 2019-03-28 22:44:41.446752                66.47          88.0
# 483 2019-03-28 22:44:41.945719                89.60          49.0
# 484 2019-03-28 22:44:42.961499                97.43          33.0
# 485 2019-03-28 22:44:44.624712                77.63          76.0
# 486 2019-03-28 22:44:44.874108                66.38          80.0
# 487 2019-03-28 22:44:45.212080                32.72          41.0
# 488 2019-03-28 22:44:46.589189                91.85          49.0
# 489 2019-03-28 22:44:48.152229                51.80          98.0
# 490 2019-03-28 22:44:53.107480                79.45          20.0
# 491 2019-03-28 22:44:54.147625                79.43          76.0
# 492 2019-03-28 22:44:55.368951                39.29          93.0
# 493 2019-03-28 22:44:57.139776                66.38          77.0
# 494 2019-03-28 22:44:58.023010                66.20          34.0
# 495 2019-03-28 22:45:00.217705                84.29          83.0
# 496 2019-03-28 22:45:02.070424                62.78          33.0
# 497 2019-03-28 22:45:02.581757                77.90          89.0
# 498 2019-03-28 22:45:02.884910                73.40          68.0
# 499 2019-03-28 22:45:03.351960                76.19          93.0
# 500 2019-03-28 22:45:06.441646                26.60          33.0
# 501 2019-03-28 22:45:08.239097                45.52          93.0
# 502 2019-03-28 22:45:11.532614                41.61          92.0
# 503 2019-03-28 22:45:12.578825                28.76          83.0
# 504 2019-03-28 22:45:13.329673                62.42          48.0
# 505 2019-03-28 22:45:16.414886                25.43          56.0
# 506 2019-03-28 22:45:18.339474                75.56          69.0
#
#      Wind Speed (mph)  Cloud Cover (%)
# 0                4.74              0.0
# 1                9.78             80.0
# 2                2.39             36.0
# 3                2.28             64.0
# 4               20.29             92.0
# 5                8.21             12.0
# 6                5.30             32.0
# 7                5.64              0.0
# 8               15.03             20.0
# 9                5.30             68.0
# 10               9.44             12.0
# 11               5.82              0.0
# 12               6.93             75.0
# 13              18.34              0.0
# 14               1.50             48.0
# 15               1.39              0.0
# 16              17.38             68.0
# 17               2.84             48.0
# 18               6.08              1.0
# 19               4.97             36.0
# 20               0.27              0.0
# 21               4.70              1.0
# 22               4.70             20.0
# 23               3.96              0.0
# 24              12.75             90.0
# 25               2.24             40.0
# 26               6.64             32.0
# 27              14.70             92.0
# 28               2.73              0.0
# 29               4.52              0.0
# ..                ...              ...
# 477              8.05             48.0
# 478              2.51             92.0
# 479              3.18             76.0
# 480              7.31              0.0
# 481              8.99              0.0
# 482              4.41              0.0
# 483              2.24             20.0
# 484              4.74              0.0
# 485              3.18              0.0
# 486              3.29              0.0
# 487             19.51             44.0
# 488              4.97              0.0
# 489              0.38             44.0
# 490             24.16             48.0
# 491             11.12             48.0
# 492              9.66             48.0
# 493             11.68              0.0
# 494              2.24              0.0
# 495              2.73             24.0
# 496              5.82             75.0
# 497              2.73             56.0
# 498              0.60             12.0
# 499              2.84              8.0
# 500              6.53             64.0
# 501              3.29             76.0
# 502             18.72              0.0
# 503              3.74             24.0
# 504             11.56             90.0
# 505              3.40             32.0
# 506              1.39             44.0
#
# [507 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind='scatter',x='Latitude',y='Temperature (deg F)',
                title='City Latitude vs. Temperature (%s)' % weather_df.loc[0,'Time'].strftime('%m/%d/%Y, %H:%M'),
                grid=True,xlim=(-90,90),color='darkblue')
plt.savefig('output_data/lat_v_temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind='scatter',x='Latitude',y='Humidity (%)',
                title='City Latitude vs. Humidity (%s)' % weather_df.loc[0,'Time'].strftime('%m/%d/%Y, %H:%M'),
                grid=True,xlim=(-90,90),color='darkblue')
plt.savefig('output_data/lat_v_humid.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind='scatter',x='Latitude',y='Cloud Cover (%)',
                title='City Latitude vs. Cloudiness (%s)' % weather_df.loc[0,'Time'].strftime('%m/%d/%Y, %H:%M'),
                grid=True,xlim=(-90,90),color='darkblue')
plt.savefig('output_data/lat_v_cloud.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind='scatter',x='Latitude',y='Wind Speed (mph)',
                title='City Latitude vs. Wind Speed (%s)' % weather_df.loc[0,'Time'].strftime('%m/%d/%Y, %H:%M'),
                grid=True,xlim=(-90,90),color='darkblue')
plt.savefig('output_data/lat_v_wind.png')

# %%
weather_df['City'].nunique()
# Out:
# 490

# %%
rs = weather_df.corr(method='spearman')
r_temp = rs.iat[2,0]
r_humid = rs.iat[3,0]
r_wind = rs.iat[4,0]
r_cloud = rs.iat[5,0]
rs
# Out:
#                      Latitude  Longitude  Temperature (deg F)  Humidity (%)  \
# Latitude             1.000000   0.047178            -0.726350     -0.070834
# Longitude            0.047178   1.000000             0.168063     -0.274746
# Temperature (deg F) -0.726350   0.168063             1.000000     -0.150199
# Humidity (%)        -0.070834  -0.274746            -0.150199      1.000000
# Wind Speed (mph)     0.219683   0.011707            -0.105762     -0.161997
# Cloud Cover (%)      0.050952  -0.077121            -0.129454      0.292784
#
#                      Wind Speed (mph)  Cloud Cover (%)
# Latitude                     0.219683         0.050952
# Longitude                    0.011707        -0.077121
# Temperature (deg F)         -0.105762        -0.129454
# Humidity (%)                -0.161997         0.292784
# Wind Speed (mph)             1.000000         0.088956
# Cloud Cover (%)              0.088956         1.000000

# %% [markdown]
# Howell (2013) - Statistical Methods for Psychology (8th ed.). provides an approximate test for significant when using Spearman's correlation coefficients, basically the same formula as for Pearson values, but with the caution that the result is qualitative.  The accepted practice is simply to note borderline cases (here if values are only slightly larger than 2) as being marginal candidates for true statistical significance at 95% confidence.

# %%
T_temp = r_temp * 488 ** 0.5 / (1 - r_temp * r_temp) ** 0.5
T_humid = r_humid * 488 ** 0.5 / (1 - r_humid * r_humid) ** 0.5
T_wind = r_wind * 488 ** 0.5 / (1 - r_wind * r_wind) ** 0.5
T_cloud = r_cloud * 488 ** 0.5 / (1 - r_cloud * r_cloud) ** 0.5
if abs(T_temp) > 3:
    print('Correlation between temperature and latitude is likely significant at 95% confidence')
elif abs(T_temp) > 2:
    print('Correlation between temperature and latitude is marginally significant at 95% confidence')
if abs(T_humid) > 3:
    print('Correlation between humidity and latitude is likely significant at 95% confidence')
elif abs(T_humid) > 2:
    print('Correlation between humidity and latitude is marginally significant at 95% confidence')
if abs(T_wind) > 3:
    print('Correlation between wind speed and latitude is likely significant at 95% confidence')
elif abs(T_wind) > 2:
    print('Correlation between wind speed and latitude is marginally significant at 95% confidence')
if abs(T_cloud) > 3:
    print('Correlation between cloud cover and latitude is likely significant at 95% confidence')
elif abs(T_cloud) > 2:
    print('Correlation between cloud cover and latitude is marginally significant at 95% confidence')
# Out:
# Correlation between temperature and latitude is likely significant at 95% confidence
# Correlation between wind speed and latitude is likely significant at 95% confidence

# %%
r_cloud
# Out:
# -0.07712080476482112
